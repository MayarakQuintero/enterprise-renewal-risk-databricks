-- %%
SELECT
  client_id,
  renewal_cycle_id,
  industry,
  company_size,
  annual_contract_value,
  non_renewal_probability,
  risk_bucket,
  revenue_at_risk
FROM renewal_dashboard_base
ORDER BY non_renewal_probability DESC
LIMIT 25
-- Out:
-- Databricks visualization. Run in Databricks to view.
