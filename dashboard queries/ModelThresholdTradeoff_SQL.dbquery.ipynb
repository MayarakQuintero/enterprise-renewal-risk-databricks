-- %%
SELECT
  threshold,
  tp,
  fp,
  tn,
  fn,
  ROUND(precision, 3) AS precision,
  ROUND(recall, 3) AS recall,
  ROUND(f1, 3) AS f1
FROM renewal_model_threshold_eval
ORDER BY threshold
-- Out:
-- Databricks visualization. Run in Databricks to view.
-- Databricks visualization. Run in Databricks to view.
-- Databricks visualization. Run in Databricks to view.
