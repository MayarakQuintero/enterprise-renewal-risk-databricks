-- %%
SELECT
  feature,
  coefficient
FROM renewal_model_coefficients
ORDER BY coefficient DESC
LIMIT 5;

SELECT
  feature,
  coefficient
FROM renewal_model_coefficients
ORDER BY coefficient ASC
LIMIT 5;
-- Out:
-- Databricks visualization. Run in Databricks to view.
-- Databricks visualization. Run in Databricks to view.
